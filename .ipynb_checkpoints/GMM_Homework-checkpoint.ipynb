# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
X, y_true = make_blobs(n_samples=400, centers=4,
                       cluster_std=0.60, random_state=0)
X = X[:, ::-1] # flip axes for better plotting
rng = np.random.RandomState(13) # Random number Generator with fixed state
X_stretched = np.dot(X, rng.randn(2, 2))
X = X_stretched
plt.scatter(X[:, 0], X[:, 1], c=y_true, s=40, cmap='viridis')

# %% [markdown]
# ### Implement the class for the GMM.
# #### Try to implement at least 3 methods for init_centers, including the method k-means.
# ##### You can also suggest and implement other methods.

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.stats import multivariate_normal

class GMM:
    
    def __init__(self, k, method='k-means', max_iter=100, tol=1e-6):
        self.k = k 
        self.method = method
        self.max_iter = max_iter
        self.tol = tol
    
    def init_centers(self, X):
        
        if self.method == 'random_mean_std':
            # generate K random means and stds
            mean_arr, cov_arr, pi_arr = "TODO", "TODO", "TODO" 
            
            return mean_arr, cov_arr, pi_arr
        
        if self.method == 'random_mean':
            
            # generate K random means
            mean_arr, cov_arr, pi_arr = "TODO", "TODO", "TODO" 
            
            return mean_arr, cov_arr, pi_arr
        
        if self.method == 'k-means':
            
            # generate initial points by KMeans algo
            mean_arr, cov_arr, pi_arr = "TODO", "TODO", "TODO" 
            
            return mean_arr, cov_arr, pi_arr
        
        if self.method == 'random_divide':
            
            # Devide data into k non-repeating samples
            
            mean_arr, cov_arr, pi_arr = "TODO", "TODO", "TODO" 
            
            return mean_arr, cov_arr, pi_arr
        
        if self.method == 'random_gammas':
            
            gamma_mtrx = "TODO"
            
            return self.maximization(X, gamma_mtrx)
        
    
    def fit(self, X):
        # TODO
            
    def loss(self, X, mean_arr, cov_arr, pi_arr):
        return "TODO"
    
    def pdf(self, x, mean, cov):
        return "pdf of x"
            
    def expectation(self, X, mean_arr, cov_arr, pi_arr):
        gamma_mtrx = np.zeros((X.shape[0], self.k))
        # TODO
        
        return gamma_mtrx

    def maximization(self, X, gamma_mtrx):
        Nk = gamma_mtrx.sum(axis=0)
        mean_arr = "TODO"
        cov_arr = "TODO"
        pi_arr = "TODO"
        return mean_arr, cov_arr, pi_arr    
        
    def predict(self, X):
        return "TODO"
    
    def predict_proba(self, X):
        return "TODO"

# %%
gmm = GMM(k=4, method='k-means')
gmm.fit(X)
pred = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=pred, s=50, cmap='viridis')
plt.scatter(gmm.mean_arr[:, 0], gmm.mean_arr[:, 1], c='black', s=200, alpha=0.5)

# %%
gmm.score
# Out:
# 767.3882457144988

# %%
gmm.predict_proba(X)
# Out:
# array([[4.17602873e-01, 2.35354868e-07, 5.82396892e-01, 1.50403039e-22],
#        [1.90419897e-17, 9.99999999e-01, 1.27817292e-09, 4.44954078e-15],
#        [2.35019840e-14, 9.99999997e-01, 2.79569429e-09, 2.85589119e-17],
#        ...,
#        [9.58356208e-37, 1.95973098e-08, 6.50174891e-08, 9.99999915e-01],
#        [1.96454728e-15, 4.29461586e-01, 5.70176454e-01, 3.61960567e-04],
#        [3.17868479e-47, 5.29434561e-14, 1.96591420e-11, 1.00000000e+00]])

# %%
gmm = GMM(k=4, method='random_mean')
gmm.fit(X)
pred = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=pred, s=50, cmap='viridis')
plt.scatter(gmm.mean_arr[:, 0], gmm.mean_arr[:, 1], c='black', s=200, alpha=0.5)

# %%
gmm = GMM(k=4, method='random_mean_std')
gmm.fit(X)
pred = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=pred, s=50, cmap='viridis')
plt.scatter(gmm.mean_arr[:, 0], gmm.mean_arr[:, 1], c='black', s=200, alpha=0.5)

# %%
gmm = GMM(k=4, method='random_divide')
gmm.fit(X)
pred = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=pred, s=50, cmap='viridis')
plt.scatter(gmm.mean_arr[:, 0], gmm.mean_arr[:, 1], c='black', s=200, alpha=0.5)

# %%
gmm = GMM(k=4, method='random_gammas')
gmm.fit(X)
pred = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=pred, s=50, cmap='viridis')
plt.scatter(gmm.mean_arr[:, 0], gmm.mean_arr[:, 1], c='black', s=200, alpha=0.5)

# %%
from sklearn.mixture import GaussianMixture

gm = GaussianMixture(n_components=4)
gm.fit(X)
prediction = gm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=prediction, s=50, cmap='viridis')
plt.scatter(gm.means_[:, 0], gm.means_[:, 1], c='black', s=200, alpha=0.5)
